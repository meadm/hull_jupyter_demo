# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 11.6 MB 7.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 347 kB 135.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 21.2 MB 29.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 509 kB 26.4 MB/s eta 0:00:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.4
#     Uninstalling numpy-1.21.4:
#       Successfully uninstalled numpy-1.21.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 2.0.2 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = pd.read_csv('germination_data.csv')
data
# Out:
#      PubChem_CID  Yeast_Inhibition_Percent  Cell_Viability_Percent  \
# 0          17520                     101.5                     3.3
# 1          27144                     100.0                    31.7
# 2          27297                     101.8                     4.7
# 3          66123                      79.5                    67.9
# 4          76937                      22.1                    59.9
# ..           ...                       ...                     ...
# 233     91624614                      -0.5                    96.6
# 234     91626508                      53.9                    98.3
# 235     91628556                      83.1                    88.7
# 236     91629266                      31.5                   103.1
# 237     91630328                       3.0                    93.3
#
#      NanoLuc_Signal_Percent_Control
# 0                              93.6
# 1                             106.3
# 2                             110.4
# ...

# %%
data.plot.bar(x='PubChem_CID')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data.plot.bar(x='PubChem_CID')
#
# File /opt/miniconda3/lib/python3.9/site-packages/pandas/plotting/_core.py:1192, in PlotAccessor.bar(self, x, y, **kwargs)
#    1102 @Appender(
#    1103     """
#    1104     See Also
#    (...)
#    1181     self, x: Hashable | None = None, y: Hashable | None = None, **kwargs
#    1182 ) -> PlotAccessor:
#    1183     """
#    1184     Vertical bar plot.
#    1185
#    (...)
#    1190     other axis represents a measured value.
#    1191     """
# -> 1192     return self(kind="bar", x=x, y=y, **kwargs)
#
# File /opt/miniconda3/lib/python3.9/site-packages/pandas/plotting/_core.py:947, in PlotAccessor.__call__(self, *args, **kwargs)
#     946 def __call__(self, *args, **kwargs):
# --> 947     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
# ...

# %%
pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 7.9 MB 6.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 265 kB 122.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 111 kB 154.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.3 MB 35.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.3 MB 33.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 65 kB 20.0 MB/s eta 0:00:011
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data.plot.bar(x='PubChem_CID')
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: xlabel='PubChem_CID'>

# %% [markdown]
# ## Boxplots

# %%
df = pd.DataFrame(np.random.randn(10, 4),

                  columns=['Col1', 'Col2', 'Col3', 'Col4'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = pd.DataFrame(np.random.randn(10, 4),
#       2
#       3                   columns=['Col1', 'Col2', 'Col3', 'Col4'])
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(10, 4),
                  columns=['Col1', 'Col2', 'Col3', 'Col4'])
df
# Out:
#        Col1      Col2      Col3      Col4
# 0  1.265877 -1.460885  0.565616  1.857749
# 1  0.629166 -2.333878  1.246585  0.201019
# 2  0.183804  2.031776 -2.169946  1.082885
# 3 -0.897029  0.340863 -1.006582 -0.000997
# 4 -0.370467  0.461980  1.717321 -1.407144
# 5 -1.292015  0.264986  0.160913 -0.892766
# 6 -1.000054 -1.036371 -0.679785  0.229438
# 7 -0.550226 -2.185787  0.135968 -0.236146
# 8 -0.531811  1.670750 -0.012389 -0.080687
# 9  0.832648  1.565283 -1.806927 -0.146213

# %%
boxplot = data.boxplot(column=['Yeast_Inhibition_Percent', 'Cell_Viability_Percent', 'NanoLuc_Signal_Percent_Control'], rot=45)

# %%
plt.savefig('ortiz_boxplot.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plt.savefig('ortiz_boxplot.png')
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.savefig('ortiz_boxplot.png')

# %% [markdown]
# didn't do anything because there was no plot in the command

# %%
data.boxplot(column=['Yeast_Inhibition_Percent', 'Cell_Viability_Percent', 'NanoLuc_Signal_Percent_Control'], rot=45)
plt.savefig('ortiz_boxplot.png', bbox_inches='tight')
